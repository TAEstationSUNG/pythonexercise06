# %%
# !pip install pandas

# %%
import pandas as pd

# %%
# pandas의 Series 기능으로 배열을 만드는 것
s = pd.Series([100, 50, 30, 10])
s
# Out:
# 0    100
# 1     50
# 2     30
# 3     10
# dtype: int64

# %%
s.index

# Series의 인덱스를 확인하는 코드
# 0부터 시작해서 4직전까지 1씩 증가 (즉 0, 1,2,3)
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
s.index = ['A', 'B', 'O', 'AB']

# %%
s.index
# Out:
# Index(['A', 'B', 'O', 'AB'], dtype='str')

# %%
s   
#위에 있던 s랑 합쳐짐. 인덱스 값으로 들어감
# Out:
# A     100
# B      50
# O      30
# AB     10
# dtype: int64

# %%
family = [['김철수', 45, '남', 175, 'A'],
          ['이영희', 43, '여', 168, 'B'],
          ['김선우', 13, '남', 160, 'A'],
          ['김지우', 10, '여', 140, 'O'],
          ['김현우',  7, '남', 125, 'AB']]

df = pd.DataFrame(family)
df

# pandas에 있는 DataFrame()으로 family라는 리스트를 데이터화
# Out:
#      0   1  2    3   4
# 0  김철수  45  남  175   A
# 1  이영희  43  여  168   B
# 2  김선우  13  남  160   A
# 3  김지우  10  여  140   O
# 4  김현우   7  남  125  AB

# %%
df.index

#start=인덱스가 시작하는 값 / stop=인덱스가 끝나는 지점
# step=인덱스 값이 얼마나 증가하는지. 연속적으로 얼마나 증가하는지 알수 있음
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df.index = ['아빠', '엄마', '첫째', '둘째', '셋째']
df.index

# df.index는 행의 이름을 관리하는 속성(세로)
# df.colums 는 열 인덱스(컬럼명)을 관리하는 속성
# Out:
# Index(['아빠', '엄마', '첫째', '둘째', '셋째'], dtype='str')

# %%
df
# Out:
#       0   1  2    3   4
# 아빠  김철수  45  남  175   A
# 엄마  이영희  43  여  168   B
# 첫째  김선우  13  남  160   A
# 둘째  김지우  10  여  140   O
# 셋째  김현우   7  남  125  AB

# %%
df.columns
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df.columns = ['이름', '나이', '성별', '키', '혈액형']
df.columns

# df.columns은 열의 이름을 지정(가로)
# Out:
# Index(['이름', '나이', '성별', '키', '혈액형'], dtype='str')

# %%
df
# Out:
#      이름  나이 성별    키 혈액형
# 아빠  김철수  45  남  175   A
# 엄마  이영희  43  여  168   B
# 첫째  김선우  13  남  160   A
# 둘째  김지우  10  여  140   O
# 셋째  김현우   7  남  125  AB

# %%
#딕셔너리 d를 만들기
# 키(열) :  값(열에 들어갈 데이터)

d = {
    '이름': ['철수', '영희', '길동', '길순', '무개'],
    '나이': [15, 16, 20, 19, 23],
    '키': [160.5, 158.3, 175.0, 178.4, 185.0]
    }

#딕셔너리를 넣으면 pandas가 자동으로 DataFrame으로 변환
#행 인덱스는 자동으로 숫자가 부여됨
df2 = pd.DataFrame(d)
df2
# Out:
#    이름  나이      키
# 0  철수  15  160.5
# 1  영희  16  158.3
# 2  길동  20  175.0
# 3  길순  19  178.4
# 4  무개  23  185.0

# %%
df3 = df2.copy()
df4 = df3.set_index('이름')     #기존에 있던 이름(열)은 사라지고, 대신 행 이름이 된다
df4
# Out:
#     나이      키
# 이름
# 철수  15  160.5
# 영희  16  158.3
# 길동  20  175.0
# 길순  19  178.4
# 무개  23  185.0

# %%
df3
# Out:
#    이름  나이      키
# 0  철수  15  160.5
# 1  영희  16  158.3
# 2  길동  20  175.0
# 3  길순  19  178.4
# 4  무개  23  185.0

# %%
df3.set_index('이름', inplace=True)
df3

# inplace = False(기본값) : 새로운 DataFrame를 만들어서 반환, 원본 안바뀜
# inplace = True : 기존 DataFrame를 직접 수정, 원본이 바로 바뀜
# Out:
#     나이      키
# 이름
# 철수  15  160.5
# 영희  16  158.3
# 길동  20  175.0
# 길순  19  178.4
# 무개  23  185.0

# %%
# CSV파일을 읽어서 DataFrame으로 만드는 코드
df4 = pd.read_csv('../data/scores.csv', encoding='cp949')
# encoding='cp949'는 윈도우에서 주로 사용하는 한국어 인코딩
df4
# Out:
#      학번      이름 성별     국어   영어     수학
# 0  2201    kate  f  100.0   90   95.0
# 1  2202  olivia  f   90.0   80   75.0
# 2  2203    emma  f   95.0  100  100.0
# 3  2204  sophia  f  100.0  100  100.0
# 4  2205     amy  f    NaN   35   60.0
# 5  2206   james  m   70.0   75   65.0
# 6  2207  daniel  m   80.0   90   55.0
# 7  2208   peter  m   50.0   60    NaN
# 8  2209   kevin  m  100.0  100   90.0
# 9  2210    jack  m   90.0   95   70.0

# %%
df5 = pd.read_csv('../data/scores.csv', encoding='utf-8')
# utf-8은 국제 표준 인코딩이지만, 한국에서 엑셀로 만든 CSV파일은 대부분 cp949로 인코딩
df5
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 df5 = pd.read_csv('../data/scores.csv', encoding='utf-8')
#       2 df5
#
# File c:\Users\EL057\Documents\20260522\.venv\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
# ...

# %%
df4.set_index('학번', inplace=True)  # 학번 열을 행 인덱스로 바꾸는 코드
df4
# Out:
#           이름 성별     국어   영어     수학
# 학번
# 2201    kate  f  100.0   90   95.0
# 2202  olivia  f   90.0   80   75.0
# 2203    emma  f   95.0  100  100.0
# 2204  sophia  f  100.0  100  100.0
# 2205     amy  f    NaN   35   60.0
# 2206   james  m   70.0   75   65.0
# 2207  daniel  m   80.0   90   55.0
# 2208   peter  m   50.0   60    NaN
# 2209   kevin  m  100.0  100   90.0
# 2210    jack  m   90.0   95   70.0

# %%
df4.shape       #(행의 개수 ,열의 개수) / 데이터가 10개, 컬럼(변수)이 5개 있다
# Out:
# (10, 5)

# %%
df4.dtypes

# dtypes는 'Data Types'의 약자로, 각 열(컬럼)의 데이터 타입을 알려주는 코드
# Out:
# 이름        str
# 성별        str
# 국어    float64
# 영어      int64
# 수학    float64
# dtype: object

# %%
df4.info()

# DataFrame의 전체적인 정보를 한번에 요약해서 보여주는 메서드
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 2201 to 2210
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   이름      10 non-null     str
#  1   성별      10 non-null     str
#  2   국어      9 non-null      float64
#  3   영어      10 non-null     int64
#  4   수학      9 non-null      float64
# dtypes: float64(2), int64(1), str(2)
# memory usage: 532.0 bytes

# %%
df4.describe()

# describe()는 데이터의 통게 요약 정보를 한 번에 보여주는 메서드
# 숫자형 컬럼(int,float)에 대해서만 자세한 통계를 보여주고
# 문자열 컬럼(이름 등)은 기본적으로 제외됩니다
# Out:
#                국어          영어          수학
# count    9.000000   10.000000    9.000000
# mean    86.111111   82.500000   78.888889
# std     16.914819   21.114766   17.638342
# min     50.000000   35.000000   55.000000
# 25%     80.000000   76.250000   65.000000
# 50%     90.000000   90.000000   75.000000
# 75%    100.000000   98.750000   95.000000
# max    100.000000  100.000000  100.000000

# %%
df4['영어'].median()

# '영어' 컬럼의 중앙값을 계산하는 코드
# df4에서 '영어' 열만 선택. 선택된 열의 중앙값을 계산
# Out:
# np.float64(90.0)

# %%
df4.value_counts('국어')

# '국어' 컬럼에 각 점수가 몇 번 등장하는지 빈도 수를 세어주는 코드
# 내림차순으로 정렬되어 나옴. 문자열 컬럼에도 사용할 수 있음. 결측치는 기본적으로 제외하고 계산
# Out:
# 국어
# 100.0    3
# 90.0     2
# 95.0     1
# 70.0     1
# 80.0     1
# 50.0     1
# Name: count, dtype: int64

# %%
df4.sort_index(ascending=False)

# 행 인덱스를 기준으로 DataFrame을 정렬하는 코드. 내림차순으로 정렬(큰값에서 작은값)
# ascending = False 는 내림차순으로 정렬
# Out:
#           이름 성별     국어   영어     수학
# 학번
# 2210    jack  m   90.0   95   70.0
# 2209   kevin  m  100.0  100   90.0
# 2208   peter  m   50.0   60    NaN
# 2207  daniel  m   80.0   90   55.0
# 2206   james  m   70.0   75   65.0
# 2205     amy  f    NaN   35   60.0
# 2204  sophia  f  100.0  100  100.0
# 2203    emma  f   95.0  100  100.0
# 2202  olivia  f   90.0   80   75.0
# 2201    kate  f  100.0   90   95.0

# %%
df4.sort_values('수학')

# '수학' 컬럼의 값을 기준으로 전체 DataFrame을 정렬하는 코드
# sort_values(수학)이니 수학 컬럼에 있는 숫자 값을 기준으로 행 전체를 재배치
# 기본 설정으로 오름차순으로 정렬
# Out:
#           이름 성별     국어   영어     수학
# 학번
# 2207  daniel  m   80.0   90   55.0
# 2205     amy  f    NaN   35   60.0
# 2206   james  m   70.0   75   65.0
# 2210    jack  m   90.0   95   70.0
# 2202  olivia  f   90.0   80   75.0
# 2209   kevin  m  100.0  100   90.0
# 2201    kate  f  100.0   90   95.0
# 2204  sophia  f  100.0  100  100.0
# 2203    emma  f   95.0  100  100.0
# 2208   peter  m   50.0   60    NaN

# %%
df4['이름']

# DataFrame에서 '이름' 컬럼만 선택하는 코드
# 아까 위에 코드에서 set_index('학번')을 했기 때문에 학번이 행의 이름(인덱스)역할하고있음
# pandas에서 하나의 열을 선택하면 인덱스 + 해당 열의 값을 함께 보여줌
# Out:
# 학번
# 2201      kate
# 2202    olivia
# 2203      emma
# 2204    sophia
# 2205       amy
# 2206     james
# 2207    daniel
# 2208     peter
# 2209     kevin
# 2210      jack
# Name: 이름, dtype: str

# %%
type(df4['이름'])

# df4['이름'] 이 어떤 데이터 타입인지 확인하는 코드
# Out:
# pandas.Series

# %%
df4.loc[2204]

# .loc[] 는 라벨 기반 인덱싱. 지금 df4는 학번으로 인덱스set이 되어있기 때문에 
# 학번이 2204인 학생의 행 전체를 선택하는 코드
# Out:
# 이름    sophia
# 성별         f
# 국어     100.0
# 영어       100
# 수학     100.0
# Name: 2204, dtype: object

# %%
df4.loc[2204, '이름']
# Out:
# 'sophia'

# %%
df4.iloc[0, 2]

# 위치(번호) 기반으로 특정 값 하나를 선택하는 코드
# .iloc 는 정수위치 기반 인덱싱. 행과 열을 0부터 시작하는 숫자 위치로 지정
# [ 행 위치, 열 위치]니까 첫번째 행의 3번째 열
# Out:
# np.float64(100.0)

# %%
df4.head(3)

# DataFrame의 맨 위에서부터 3개의 행만 보여주는 코드
# Out:
#           이름 성별     국어   영어     수학
# 학번
# 2201    kate  f  100.0   90   95.0
# 2202  olivia  f   90.0   80   75.0
# 2203    emma  f   95.0  100  100.0

# %%
df4.loc[2201]

# 학번이 2201인 학생의 행 전체를 선택해서 보여주는 코드
# .loc[]는 라벨(이름)을 기반으로 데이터를 선택하는 방법
# Out:
# 이름     kate
# 성별        f
# 국어    100.0
# 영어       90
# 수학     95.0
# Name: 2201, dtype: object

# %%
df4.loc[[2201]]

# 이 코드는 학번이 2201인 학생의 정보를 DataFrame형태로 가져오는 코드
# Out:
#         이름 성별     국어  영어    수학
# 학번
# 2201  kate  f  100.0  90  95.0

# %%
df4.loc[[2201, 2202]]
# Out:
#           이름 성별     국어  영어    수학
# 학번
# 2201    kate  f  100.0  90  95.0
# 2202  olivia  f   90.0  80  75.0

# %%
df4.loc[2201, '영어']

# 학번이 2201인 학생의 영어 점수만 정확히 하나 가져오는 코드
# Out:
# np.int64(90)

# %%
df4.loc[2201, 2202]

# df4에서 학번이 2201이고 컬럼 이름이 2202인 열이 있어야하는데 df4에는 2202라는 컬럼은 없다
# 그래서 KeyError 발생
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\EL057\Documents\20260522\.venv\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
# --> 176 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:583, in pandas._libs.index.StringObjectEngine._check_type()
# --> 583 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 2202
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df4.loc[2201:2203]

# 학번이 2201부터 2203까지인 학생들의 정보를 가져오는 코드
# .loc[]에서 : 을 사용하면 범위를 지정할 수 있다
# Out:
#           이름 성별     국어   영어     수학
# 학번
# 2201    kate  f  100.0   90   95.0
# 2202  olivia  f   90.0   80   75.0
# 2203    emma  f   95.0  100  100.0

# %%
df4.loc[2202, ['영어', '수학']]

#  2202인 행의 영어와 수학만 골라서 보여달라는 코드
# Out:
# 영어    80.0
# 수학    75.0
# Name: 2202, dtype: float64

# %%
df4.loc[2202:2205, ['영어', '수학']]

# 학번이 2202부터 2205까지의 모든 행을 가져오고 그 행들의 영어와 수학 점수만 골라서 보여달라는 코드
# Out:
#        영어     수학
# 학번
# 2202   80   75.0
# 2203  100  100.0
# 2204  100  100.0
# 2205   35   60.0

# %%
df4.loc[[2202, 2210], ['영어', '수학']]

# 2022번인 행ㅇ과 2210번인 행만 고르고
# 그 행들의 영어와 수학 점수만 뽑아서 보여달라는 코드
# Out:
#       영어    수학
# 학번
# 2202  80  75.0
# 2210  95  70.0

# %%
df4.iloc[0]

# .iloc[]는 이름 상관없이 몇번째 인덱스인지를 기준으로 찾음
# 학번 이름이 2201이든 뭐든 상관없이 맨 위에 있는 첫번째 줄을 통째로 가져옴
# Out:
# 이름     kate
# 성별        f
# 국어    100.0
# 영어       90
# 수학     95.0
# Name: 2201, dtype: object

# %%
df4.iloc[2:5,[4, 2, 0]]

# df4라는 표에서 컴퓨터 순서 기준으로 2,3,4번째 행을 가져오고
# 열은 4,2,0번째 열만 골라서 순서대로 보여줘 라는 뜻
# Out:
#          수학     국어      이름
# 학번
# 2203  100.0   95.0    emma
# 2204  100.0  100.0  sophia
# 2205   60.0    NaN     amy

# %%
df4.head(3)
# Out:
#           이름 성별     국어   영어     수학
# 학번
# 2201    kate  f  100.0   90   95.0
# 2202  olivia  f   90.0   80   75.0
# 2203    emma  f   95.0  100  100.0

# %%
df4['영어']
# Out:
# 학번
# 2201     90
# 2202     80
# 2203    100
# 2204    100
# 2205     35
# 2206     75
# 2207     90
# 2208     60
# 2209    100
# 2210     95
# Name: 영어, dtype: int64

# %%
df4[['영어', '수학']]
# Out:
#        영어     수학
# 학번
# 2201   90   95.0
# 2202   80   75.0
# 2203  100  100.0
# 2204  100  100.0
# 2205   35   60.0
# 2206   75   65.0
# 2207   90   55.0
# 2208   60    NaN
# 2209  100   90.0
# 2210   95   70.0

# %%
df4.loc[2203, ['국어', '영어', '수학']]

# 2203번의 국어,영어,수학 점수를 한번에 보여달라는 코드
# Out:
# 국어     95.0
# 영어    100.0
# 수학    100.0
# Name: 2203, dtype: float64

# %%
df4.loc[[2201, 2205], ['이름']]
# Out:
#         이름
# 학번
# 2201  kate
# 2205   amy

# %%
df4.loc[[2201, 2205], '이름']
# Out:
# 학번
# 2201    kate
# 2205     amy
# Name: 이름, dtype: str

# %%
df4.loc[[2201, 2205], ['이름', '수학']]

# df4.loc [ [행 리스트], [열 리스트]]
# Out:
#         이름    수학
# 학번
# 2201  kate  95.0
# 2205   amy  60.0

# %%
df4.loc[df4['국어']==100]
# Out:
#           이름 성별     국어   영어     수학
# 학번
# 2201    kate  f  100.0   90   95.0
# 2204  sophia  f  100.0  100  100.0
# 2209   kevin  m  100.0  100   90.0

# %%
df4.loc[df4['국어']==100, ['이름','성별','국어']]
# Out:
#           이름 성별     국어
# 학번
# 2201    kate  f  100.0
# 2204  sophia  f  100.0
# 2209   kevin  m  100.0

# %%
df4.loc[(df4['국어']==100) & (df4['영어']==100) & (df4['수학']==100)]
# Out:
#           이름 성별     국어   영어     수학
# 학번
# 2204  sophia  f  100.0  100  100.0

# %%
df4.loc[(df4['국어']==100) | (df4['영어']==100) | (df4['수학']==100)]
# Out:
#           이름 성별     국어   영어     수학
# 학번
# 2201    kate  f  100.0   90   95.0
# 2203    emma  f   95.0  100  100.0
# 2204  sophia  f  100.0  100  100.0
# 2209   kevin  m  100.0  100   90.0

# %%
df4['평균'] = round((df4['국어'] + df4['영어'] + df4['수학'])/3, 1)

# 국어,영어,수학 점수를 다 더해서 3으로 나눈 평균값을 구한 뒤, 소수점 둘째 자리에서 반올림
# 소수점 첫째 자리까지만 정리해달라는 것
# round(값, 자릿 수) : 파이썬에서 반올림을 해주는 함수
# 만들어서 새로운 '평균' 컬럼을 만드는게 맞음
df4
# Out:
#           이름 성별     국어   영어     수학     평균
# 학번
# 2201    kate  f  100.0   90   95.0   95.0
# 2202  olivia  f   90.0   80   75.0   81.7
# 2203    emma  f   95.0  100  100.0   98.3
# 2204  sophia  f  100.0  100  100.0  100.0
# 2205     amy  f    NaN   35   60.0    NaN
# 2206   james  m   70.0   75   65.0   70.0
# 2207  daniel  m   80.0   90   55.0   75.0
# 2208   peter  m   50.0   60    NaN    NaN
# 2209   kevin  m  100.0  100   90.0   96.7
# 2210    jack  m   90.0   95   70.0   85.0

# %%
df4.drop(columns=['평균'])

# drop() 함수는 원본을 삭제가 아니라 평균 컬럼을 삭제한 걸 보여줌
# Out:
#           이름 성별     국어   영어     수학
# 학번
# 2201    kate  f  100.0   90   95.0
# 2202  olivia  f   90.0   80   75.0
# 2203    emma  f   95.0  100  100.0
# 2204  sophia  f  100.0  100  100.0
# 2205     amy  f    NaN   35   60.0
# 2206   james  m   70.0   75   65.0
# 2207  daniel  m   80.0   90   55.0
# 2208   peter  m   50.0   60    NaN
# 2209   kevin  m  100.0  100   90.0
# 2210    jack  m   90.0   95   70.0

# %%
df4
# Out:
#           이름 성별     국어   영어     수학     평균
# 학번
# 2201    kate  f  100.0   90   95.0   95.0
# 2202  olivia  f   90.0   80   75.0   81.7
# 2203    emma  f   95.0  100  100.0   98.3
# 2204  sophia  f  100.0  100  100.0  100.0
# 2205     amy  f    NaN   35   60.0    NaN
# 2206   james  m   70.0   75   65.0   70.0
# 2207  daniel  m   80.0   90   55.0   75.0
# 2208   peter  m   50.0   60    NaN    NaN
# 2209   kevin  m  100.0  100   90.0   96.7
# 2210    jack  m   90.0   95   70.0   85.0

# %%
df4.isnull().sum()

# isnull()은 표 전체에 결측치가 있는지 확인 있으면 false, 빈칸(결측치)가 있다면 True
# True가 1이니까 더할때마다 1씩 올라가고, 각 컬럼마다 빈칸이 있는지 표시
# Out:
# 이름    0
# 성별    0
# 국어    1
# 영어    0
# 수학    1
# 평균    2
# dtype: int64

# %%
# 표에서 빈칸이 있는 행은 통째로 삭제
df4.dropna()
# Out:
#           이름 성별     국어   영어     수학     평균
# 학번
# 2201    kate  f  100.0   90   95.0   95.0
# 2202  olivia  f   90.0   80   75.0   81.7
# 2203    emma  f   95.0  100  100.0   98.3
# 2204  sophia  f  100.0  100  100.0  100.0
# 2206   james  m   70.0   75   65.0   70.0
# 2207  daniel  m   80.0   90   55.0   75.0
# 2209   kevin  m  100.0  100   90.0   96.7
# 2210    jack  m   90.0   95   70.0   85.0

# %%
df4
# Out:
#           이름 성별     국어   영어     수학     평균
# 학번
# 2201    kate  f  100.0   90   95.0   95.0
# 2202  olivia  f   90.0   80   75.0   81.7
# 2203    emma  f   95.0  100  100.0   98.3
# 2204  sophia  f  100.0  100  100.0  100.0
# 2205     amy  f    NaN   35   60.0    NaN
# 2206   james  m   70.0   75   65.0   70.0
# 2207  daniel  m   80.0   90   55.0   75.0
# 2208   peter  m   50.0   60    NaN    NaN
# 2209   kevin  m  100.0  100   90.0   96.7
# 2210    jack  m   90.0   95   70.0   85.0

# %%
df4.ffill()

# ffill()은 전방의 데이터로 결측치 대체(결측치 값 기준으로 위의 값)
# Out:
#           이름 성별     국어   영어     수학     평균
# 학번
# 2201    kate  f  100.0   90   95.0   95.0
# 2202  olivia  f   90.0   80   75.0   81.7
# 2203    emma  f   95.0  100  100.0   98.3
# 2204  sophia  f  100.0  100  100.0  100.0
# 2205     amy  f  100.0   35   60.0  100.0
# 2206   james  m   70.0   75   65.0   70.0
# 2207  daniel  m   80.0   90   55.0   75.0
# 2208   peter  m   50.0   60   55.0   75.0
# 2209   kevin  m  100.0  100   90.0   96.7
# 2210    jack  m   90.0   95   70.0   85.0

# %%
df4.bfill()

# bfill()은 후방의 데이터로 결측치 대체
# Out:
#           이름 성별     국어   영어     수학     평균
# 학번
# 2201    kate  f  100.0   90   95.0   95.0
# 2202  olivia  f   90.0   80   75.0   81.7
# 2203    emma  f   95.0  100  100.0   98.3
# 2204  sophia  f  100.0  100  100.0  100.0
# 2205     amy  f   70.0   35   60.0   70.0
# 2206   james  m   70.0   75   65.0   70.0
# 2207  daniel  m   80.0   90   55.0   75.0
# 2208   peter  m   50.0   60   90.0   96.7
# 2209   kevin  m  100.0  100   90.0   96.7
# 2210    jack  m   90.0   95   70.0   85.0

# %%
df4.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 2201 to 2210
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   이름      10 non-null     str
#  1   성별      10 non-null     str
#  2   국어      9 non-null      float64
#  3   영어      10 non-null     int64
#  4   수학      9 non-null      float64
#  5   평균      8 non-null      float64
# dtypes: float64(3), int64(1), str(2)
# memory usage: 612.0 bytes

# %%
df4.astype({'영어':'float64'})

# as type(~ 형태로)변경하는 코드
# Out:
#           이름 성별     국어     영어     수학     평균
# 학번
# 2201    kate  f  100.0   90.0   95.0   95.0
# 2202  olivia  f   90.0   80.0   75.0   81.7
# 2203    emma  f   95.0  100.0  100.0   98.3
# 2204  sophia  f  100.0  100.0  100.0  100.0
# 2205     amy  f    NaN   35.0   60.0    NaN
# 2206   james  m   70.0   75.0   65.0   70.0
# 2207  daniel  m   80.0   90.0   55.0   75.0
# 2208   peter  m   50.0   60.0    NaN    NaN
# 2209   kevin  m  100.0  100.0   90.0   96.7
# 2210    jack  m   90.0   95.0   70.0   85.0

# %%
df4
# Out:
#           이름 성별     국어   영어     수학     평균
# 학번
# 2201    kate  f  100.0   90   95.0   95.0
# 2202  olivia  f   90.0   80   75.0   81.7
# 2203    emma  f   95.0  100  100.0   98.3
# 2204  sophia  f  100.0  100  100.0  100.0
# 2205     amy  f    NaN   35   60.0    NaN
# 2206   james  m   70.0   75   65.0   70.0
# 2207  daniel  m   80.0   90   55.0   75.0
# 2208   peter  m   50.0   60    NaN    NaN
# 2209   kevin  m  100.0  100   90.0   96.7
# 2210    jack  m   90.0   95   70.0   85.0

# %%
# df4.astype({'영어':'float64'}, inplace=True)
#영어 점수를 실수형으로 바꾸고 inplace=True를 써서 원본 표를 고쳐달라는건데 이거 에러
# .astype()함수는 inplace=True옵션을 지원하지않음

# df4 = df4.astype({'영어':'float64'})
#영어 점수를 실수형으로 바꾼 새로운 복사본 표를 만든뒤, 그걸 원래이름인 df4에 그대로 덮어
# .astype()는 무조건 변환된 새로운 표를 복사본으로 복제해줌

# %%
# !pip install matplotlib

# 파이썬에서 데이터로 표나 그래프(차트)를 그려주는 가장 대표적인 그림 라이브러리

# %%
import matplotlib.pyplot as plt

# %%
plt.rc('font', family='Malgun Gothic')      # 맑은 고딕 폰트
plt.rc('axes', unicode_minus=False)         # 한글과 세트로 다니는 기호 깨짐 방지설정

# %%
pd.Series([-1, 2, 3]).plot(title='테스트', figsize=(3, 2))

# [-1, 2, 3]이라는 숫자 3개가 세로로 나열된 한 줄짜리 데이터(시리즈)를 만든 것
# .plot()를 붙이면 그래프를 그리는 명령
# title=테스트 라고 하면 제목을 달아준거
# figsize=(3,2)는 가로 3인치, 세로 2인치를 지정해준 것

# 첫번째 점은 : 높이 -1 / 두번째 점: 높이 2 / 세번째 점 : 높이 3
# Out:
# <Axes: title={'center': '테스트'}>

# %%
pd.Series([-1, 2, 3]).plot(title='테스트', figsize=(3, 2))
pass

# pass는 컴퓨터 메시지(텍스트)가 함께 출력되는걸 없애줌

# %%
df4.plot(kind='bar', y='국어', figsize=(4,3), color='red', title='국어점수')
pass

# 세로 막대형으로 변경. 가로 4인치, 세로 3인치 크기의 표
